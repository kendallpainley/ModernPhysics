# %% [markdown]
# ### What Speeds are Relativistic?
# How fast must a vehicle travel for $1$ second of time measured on a passenger’s watch in the vehicle to differ by
# $1%$ for an observer measuring it from the ground outside?

# %% [markdown]
# ### Strategy
#
# Use the time dilation formula to find $v/c$ for the given ratio of times
#
# We want a 1% difference, meaning the ground observer measures 1.01 seconds for every 1 second on the passenger's watch
#
# - The ratio of the two times: $\frac{\Delta\tau}{\Delta t} = \frac{1}{1.01}$
# - We want to find $v/c$

# %% [markdown]
# **Step 1: Write down the formula and identify what we're solving for**
#
# Start with the time dilation formula:
#
# $$\Delta t = \frac{\Delta\tau}{\sqrt{1 - v^2/c^2}}$$
#
# Here we know the ratio $\Delta\tau / \Delta t$ and need to solve for $v/c$.
#
# ---
#
# **Step 2: Rearrange the formula to isolate the square root**
#
# Starting from:
#
# $$\Delta t = \frac{\Delta\tau}{\sqrt{1 - v^2/c^2}}$$
#
# Divide both sides by $\Delta t$ and multiply both sides by $\sqrt{1 - v^2/c^2}$:
#
# $$\sqrt{1 - v^2/c^2} = \frac{\Delta\tau}{\Delta t}$$
#
# ---
#
# **Step 3: Square both sides to remove the square root**
#
# $$1 - \frac{v^2}{c^2} = \left(\frac{\Delta\tau}{\Delta t}\right)^2$$
#
# Rearrange to get $v^2/c^2$ on its own:
#
# $$\frac{v^2}{c^2} = 1 - \left(\frac{\Delta\tau}{\Delta t}\right)^2$$
#
# Finally, take the square root of both sides to get $v/c$:
#
# $$\frac{v}{c} = \sqrt{1 - \left(\frac{\Delta\tau}{\Delta t}\right)^2}$$
#
# ---
#
# **Step 4: Plug in the numbers**
#
# $$\frac{\Delta\tau}{\Delta t} = \frac{1}{1.01} \approx 0.9901$$
#
# Substitute into the formula:
#
# $$\frac{v}{c} = \sqrt{1 - \left(\frac{1}{1.01}\right)^2}$$
#
#
# $$\left(\frac{1}{1.01}\right)^2 = (0.9901)^2 = 0.9803$$
#
#
# $$1 - 0.9803 = 0.0197$$
#
#
# $$\frac{v}{c} = \sqrt{0.0197} \approx 0.14$$
#
#
# $$\boxed{\frac{v}{c} \approx 0.14}$$
#
# To produce a time dilation effect of just 1%, the vehicle must be travelling at 14% of the speed of light.
